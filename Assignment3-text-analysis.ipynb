# %% [markdown]
# # Assignment 3 - Text Analysis
# An explanation this assignment could be found in the .pdf explanation document

# %% [markdown]
# ## Materials to review for this assignment
# <h4>From Moodle:</h4>
# <h5><u>Review the notebooks regarding the following python topics</u>:</h5>
# <div class="alert alert-info">
# &#x2714; <b>Working with strings</b> (tutorial notebook)<br/>
# &#x2714; <b>Text Analysis</b> (tutorial notebook)<br/>
# &#x2714; <b>Hebrew text analysis tools (tokenizer, wordnet)</b> (moodle example)<br/>
# &#x2714; <b>(brief review) All previous notebooks</b><br/>
# </div>
# <h5><u>Review the presentations regarding the following topics</u>:</h5>
# <div class="alert alert-info">
# &#x2714; <b>Text Analysis</b> (lecture presentation)<br/>
# &#x2714; <b>(brief review) All other presentations</b><br/>
# </div>

# %% [markdown]
# ## Personal Details:

# %%
# Details Student 1:

# Details Student 2:

# %% [markdown]
# ## Preceding Step - import modules (packages)
# This step is necessary in order to use external modules (packages). <br/>

# %%
# --------------------------------------
import pandas as pd
import numpy as np
# --------------------------------------


# --------------------------------------
# ------------- visualizations:
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# --------------------------------------


# ---------------------------------------
import sklearn
from sklearn import preprocessing, metrics, pipeline, model_selection, feature_extraction 
from sklearn import naive_bayes, linear_model, svm, neural_network, neighbors, tree
from sklearn import decomposition, cluster

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV 
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import mean_squared_error, r2_score, silhouette_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler, LabelEncoder

from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import Perceptron, SGDClassifier
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SelectKBest # <-- added by me
from sklearn.feature_selection import mutual_info_classif # <-- added by me
from sklearn.preprocessing import MaxAbsScaler # <-- added by me
from sklearn.model_selection import RepeatedKFold # <-- added by me
from sklearn.metrics import make_scorer # <-- added by me
# ---------------------------------------


# ----------------- output and visualizations: 
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.simplefilter("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter("ignore", category=ConvergenceWarning)
# show several prints in one cell. This will allow us to condence every trick in one cell.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline
pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# ---------------------------------------

# %% [markdown]
# ### Text analysis and String manipulation imports:

# %%
# --------------------------------------
# --------- Text analysis and Hebrew text analysis imports:
# vectorizers:
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# regular expressions:
import re
# --------------------------------------

# %% [markdown]
# ### (optional) Hebrew text analysis - WordNet (for Hebrew)
# Note: the WordNet is not a must

# %% [markdown]
# #### (optional) Only if you didn't install Wordnet (for Hebrew) use:

# %%
# word net installation:

# unmark if you want to use and need to install
# !pip install wn
# !python -m wn download omw-he:1.4
# Out:
# ...
# Cached file found: /Users/alexgurinovich/.wn_data/downloads/7ecf10e89326bc0ac26ad94b40fe60a7b6ac3302
# Skipping omw-he:1.4 (Hebrew Wordnet); already added00gn/T/tmpbqrsag20/omw-he/omw-he.xml

# %%
# word net import:

# unmark if you want to use:
import wn

# %% [markdown]
# ### (optional) Hebrew text analysis - hebrew_tokenizer (Tokenizer for Hebrew)
# Note: the hebrew_tokenizer is not a must

# %% [markdown]
# #### (optional) Only if you didn't install hebrew_tokenizer use:

# %%
# Hebrew tokenizer installation:

# unmark if you want to use and need to install:
# !pip install hebrew_tokenizer

# %%
# Hebrew tokenizer import:

# unmark if you want to use:
import hebrew_tokenizer as ht

# %% [markdown]
# ### Reading input files
# Reading input files for train annotated corpus (raw text data) corpus and for the test corpus

# %%
train_filename = 'annotated_corpus_for_train.csv'
test_filename  = 'corpus_for_test.csv'
df_train = pd.read_csv(train_filename, index_col=None, encoding='utf-8')
df_test  = pd.read_csv(test_filename, index_col=None, encoding='utf-8')

# %%
df_train.head(8)
df_train.shape
# Out:
#                                                story gender
# 0  כשחבר הזמין אותי לחול, לא באמת חשבתי שזה יקרה,...      m
# 1  לפני שהתגייסתי לצבא עשיתי כל מני מיונים ליחידו...      m
# 2  מאז שהתחילו הלימודים חלומו של כל סטודנט זה הפנ...      f
# 3  כשהייתי ילד, מטוסים היה הדבר שהכי ריתק אותי. ב...      m
# 4  ‏הייתי מדריכה בכפר נוער ומתאם הכפר היינו צריכי...      f
# 5  לפני כ3 חודשים טסתי לרומא למשך שבוע. טסתי במטו...      f
# 6  אני כבר שנתיים נשוי והשנה אני ואישתי סוף סוף י...      m
# 7  השנה התחלנו שיפוץ בדירה שלנו בתל אביב. הדירה ה...      f
# (753, 2)

# %%
df_test.head(3)
df_test.shape
# Out:
#    test_example_id                                              story
# 0                0  כל קיץ אני והמשפחה נוסעים לארצות הברית לוס אנג...
# 1                1  הגעתי לשירות המדינה אחרי שנתיים כפעיל בתנועת "...
# 2                2  אחת האהבות הגדולות שלי אלו הכלבים שלי ושל אישת...
# (323, 2)

# %% [markdown]
# ### Your implementation:
# Write your code solution in the following code-cells

# %%
# Cleans and preprocesses text data within a DataFrame by removing digits, special characters, and extra spaces.
def df_clean(df):
    for i in df.index:
        df.loc[i, "story"] = re.sub(r'\d+', '', df.loc[i, "story"])
        df.loc[i, "story"] = re.sub(r'[^\w\s]', '', df.loc[i, "story"])
        df.loc[i, "story"] = re.sub(r'\s+', ' ', df.loc[i, "story"])
        df.loc[i, "story"] = df.loc[i, "story"].strip()
    return df

# Splits a DataFrame into training and testing sets, returning the textual data and corresponding labels for both sets.
def train_test_split_func(df):
    X_train, X_test, y_train, y_test = train_test_split(df["story"], df["gender"], test_size=0.2, random_state=42)
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test_split_func(df_train)

# %%
# Converts text data into TF-IDF feature vectors for both training and testing sets, with adjustable n-gram range and minimum document frequency.
def TfidfVectorizer_func(X_train, X_test, ngram_range = (1,1), min_df = 5):
    count_idf = TfidfVectorizer(min_df = min_df, ngram_range=ngram_range)
    X_train_idf = count_idf.fit_transform(X_train)
    X_test_idf = count_idf.transform(X_test)
    return X_train_idf, X_test_idf

# Selects the top k best features from the TF-IDF vectors based on mutual information scores for classification.
def select_best_features(X_train, X_test, y_train, k=1000):
    select_best = SelectKBest(mutual_info_classif, k=k)
    select_best.fit(X_train, y_train)
    X_train_select = select_best.transform(X_train)
    X_test_select = select_best.transform(X_test)
    return X_train_select, X_test_select

# Scales the selected features using MaxAbsScaler to ensure consistent and comparable magnitudes across the data.
def preform_MaxAbsScale(X_train_select, X_test_select):
    scaler = MaxAbsScaler()
    X_train_scaled = scaler.fit_transform(X_train_select)
    X_test_scaled = scaler.transform(X_test_select)
    return X_train_scaled, X_test_scaled

# %%
X_train_idf, X_test_idf = TfidfVectorizer_func(X_train, X_test)
X_train_select, X_test_select = select_best_features(X_train_idf, X_test_idf, y_train)
X_train_scale, X_test_scale = preform_MaxAbsScale(X_train_select, X_test_select)

# %%
# Performs grid search to optimize hyperparameters for the classification model, using params, and training data.
def find_best_params_grid_search(model_clf, model_parameters, X_train, y_train):
    grid_search = GridSearchCV(model_clf, model_parameters, cv = 5, n_jobs=-1)
    grid_search.fit(X_train, y_train)
    return grid_search.best_params_

# %%
# Optimize linear classification with varied regularization and penalty options.
Linear_svc_parmas = [{'C': [0.01, 0.1, 1, 10, 100], 'penalty': [None, 'l1', 'l2'], 'dual': [False]}]
best_params_linear_svc = find_best_params_grid_search(LinearSVC(), Linear_svc_parmas, X_train_scale, y_train)
print('Best parameters for linear_svc:')
print(best_params_linear_svc)

# Find optimal configuration for a single-layer perceptron.
Perceptron_params = [{'alpha': [0.0001, 0.05], 'penalty': [None, 'l2', 'l1', 'elasticnet']}]
best_params_perceptron = find_best_params_grid_search(Perceptron(), Perceptron_params, X_train_scale, y_train)
print('Best parameters for perceptron:')
print(best_params_perceptron)

# Tune decision tree parameters for classification.
DecisionTree_params = [{'criterion': ['gini', 'entropy'],'max_depth': [None, 5, 10, 20],'min_samples_split': [2, 5, 10],'min_samples_leaf': [1, 2, 4],'max_features': ['auto', 'sqrt', 'log2']}]
best_params_decision_tree = find_best_params_grid_search(DecisionTreeClassifier(), DecisionTree_params, X_train_scale, y_train)
print('Best parameters for decision_tree:')
print(best_params_decision_tree)

# Optimize parameters for the Multinomial Naive Bayes classifier.
MultinomailNB_parmas = [{'alpha': [0.01, 0.1, 0.5, 1], 'fit_prior': [True, False], 'class_prior': [None, [0.5, 0.5], [0.3, 0.7]]}]
best_params_MultinomialNB = find_best_params_grid_search(MultinomialNB(), MultinomailNB_parmas, X_train_scale, y_train)
print('Best parameters for MultinomialNB:')
print(best_params_MultinomialNB)

# Search for optimal settings in a multi-layer perceptron model.
MLP_params = [{'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)], 'activation': ['tanh', 'relu'],
               'solver': ['sgd', 'adam'], 'alpha': [0.0001, 0.05], 'learning_rate': ['constant','adaptive']}]
best_params_MLP = find_best_params_grid_search(MLPClassifier(),MLP_params, X_train_scale, y_train)
print('Best parameters for MLP:')
print(best_params_MLP)
# Out:
# /Users/alexgurinovich/anaconda3/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/alexgurinovich/anaconda3/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/alexgurinovich/anaconda3/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/alexgurinovich/anaconda3/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /Users/alexgurinovich/anaconda3/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
Linear_model = LinearSVC(**best_params_linear_svc)
Perceptron_model = Perceptron(**best_params_perceptron)
DecisionTree_model = DecisionTreeClassifier(**best_params_decision_tree)
MultinomialNB_model = MultinomialNB(**best_params_MultinomialNB)
MLP_model = MLPClassifier(**best_params_MLP)

# %%
# Trains a model, assesses cross-validated F1 scores, and calculates average F1 for male and female classes. Returns model and average F1.
def fit_predict_evaluate(model_name, X_train, X_test, y_train, y_test):
    model_trained = model_name.fit(X_train, y_train)
    cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=42)
    f1_scorer = make_scorer(f1_score, average='micro')
    scores = cross_val_score(model_trained, X_test, y_test, scoring=f1_scorer, cv=cv, n_jobs=-1)
    y_pred = model_trained.predict(X_test)
    f1_male = f1_score(y_test, y_pred, pos_label="m")
    f1_female = f1_score(y_test, y_pred, pos_label="f")
    f1_average = (f1_male + f1_female) / 2
    return model_trained, f1_average

# %%
linear_trained, f1_average_linear = fit_predict_evaluate(Linear_model, X_train_scale, X_test_scale, y_train, y_test)
print("f1_score Linear_svc:")
print(f1_average_linear)

perceptron_trained, f1_average_perceptron = fit_predict_evaluate(Perceptron_model, X_train_scale, X_test_scale, y_train, y_test)
print("f1_score perceptron:")
print(f1_average_perceptron)

decision_tree_trained, f1_average_decision_tree = fit_predict_evaluate(DecisionTree_model, X_train_scale, X_test_scale, y_train, y_test)
print("f1_score Decision Tree:")
print(f1_average_decision_tree)

MultinomialNB_trained, f1_average_MultinomialNB = fit_predict_evaluate(MultinomialNB_model, X_train_scale, X_test_scale, y_train, y_test)
print("f1_score MultinomialNB:")
print(f1_average_MultinomialNB)

MLP_trained, f1_average_MLP = fit_predict_evaluate(MLP_model, X_train_scale, X_test_scale, y_train, y_test)
print("f1_score MLP:")
print(f1_average_MLP)
# Out:
# f1_score Linear_svc:
# 0.6799039005087619
# f1_score perceptron:
# 0.43018867924528303
# f1_score Decision Tree:
# 0.5383831521739131
# f1_score MultinomialNB:
# 0.693089430894309
# f1_score MLP:
# 0.696137617656605

# %%
# Transforms input data X into TF-IDF feature vectors using specified n-gram range and minimum document frequency.
def TfidfVectorizer_func_test(X, ngram_range = (1,1), min_df = 5):
    count_idf = TfidfVectorizer(min_df = min_df, ngram_range=ngram_range)
    X = count_idf.fit_transform(X)
    return X

# Selects the top k best features from the input data X based on mutual information scores for classification.
def select_best_features_test(X, k=1000):
    select_best = SelectKBest(mutual_info_classif, k=k)
    X_test_selected = select_best.fit_transform(X, np.zeros(X.shape[0]))
    return X_test_selected

# Scales the input data X_train_select using Min-Max scaling to ensure values are within a specified range.
def preform_MinMaxScale_test(X_train_select):
    scale = MinMaxScaler()
    X_train_scale = scale.fit_transform(X_train_select.toarray())
    return X_train_scale

# %%
X_df_test = df_test["story"]
X_df_test = TfidfVectorizer_func_test(X_df_test)
X_df_test = select_best_features_test(X_df_test)
X_df_test_scaled = preform_MinMaxScale_test(X_df_test)
y_prediction_test = linear_trained.predict(X_df_test_scaled)

df_text_exmp = df_test["test_example_id"]
df_predicted = pd.DataFrame({"test_example_id": df_text_exmp.tolist(),
                             "predicted_category": y_prediction_test.tolist()})

# %% [markdown]
# ### Save output to csv (optional)
# After you're done save your output to the 'classification_results.csv' csv file.<br/>
# We assume that the dataframe with your results contain the following columns:
# * column 1 (left column): 'test_example_id'  - the same id associated to each of the test stories to be predicted.
# * column 2 (right column): 'predicted_category' - the predicted gender value for each of the associated story.
#
# Assuming your predicted values are in the `df_predicted` dataframe, you should save you're results as following:

# %%
df_predicted.to_csv('classification_results.csv',index=False)
